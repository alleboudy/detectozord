# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.metrics import roc_curve, auc

# %%
df = np.loadtxt("E:\\Dropbox\\Master Course\\SEM-3\\ML\\Monk\\AA1_Monks\\AA1_Monks\\bin\\Debug\\ROC.log", skiprows=1, dtype = np.float32 ,delimiter = ",")

# %%
print df[:,0]
# Out:
# [ 1.          0.4852941   0.4509804   0.4509804   0.4509804   0.4509804
#   0.4509804   0.4509804   0.4509804   0.4509804   0.4509804   0.4509804
#   0.4509804   0.4509804   0.4509804   0.4509804   0.4509804   0.4509804
#   0.44117647  0.41176471]

# %%
print df[:,1]
# Out:
# [ 1.          0.60087717  0.57017541  0.54385966  0.54385966  0.54385966
#   0.54385966  0.54385966  0.54385966  0.54385966  0.54385966  0.54385966
#   0.54385966  0.54385966  0.54385966  0.54385966  0.54385966  0.54385966
#   0.54385966  0.5350877 ]

# %%
roc_auc = auc(df[:,0], df[:,1])
plt.figure()
lw = 2
plt.plot(df[:,0], df[:,1], color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.metrics import roc_curve, auc

# %%
df = pd.read_csv("C:/Users/ahmad/Source/Repos/Monks/AA1_Monks/AA1_MLP/bin/Debug/learningcurve.txt")

# %%
df = pd.read_csv("E:/Dropbox/Master Course/SEM-3/ML/Monk/AA1_Monks/AA1_MLP/bin/Debug/learningcurve.txt")

# %%
df.plot()
